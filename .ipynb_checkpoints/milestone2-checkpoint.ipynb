# %%
# IMPORTS
import altair as alt
import pandas as pd
from vega_datasets import data

food_emissions = pd.read_excel("/Users/aksharkatariya/Documents/GitHub/static_project/EDGAR-FOOD_v6.xlsx", sheet_name="emissions", header=3)
shares = pd.read_excel("/Users/aksharkatariya/Documents/GitHub/static_project/EDGAR-FOOD_v6.xlsx", sheet_name="shares", header=3)
sector = pd.read_excel("/Users/aksharkatariya/Documents/GitHub/static_project/EDGAR-FOOD_v6.xlsx", sheet_name="sector", header=3)
country_definition = pd.read_excel("/Users/aksharkatariya/Documents/GitHub/static_project/EDGAR-FOOD_v6.xlsx", sheet_name="country_definition", header=3)

# %% [markdown]
# # Exploring Data

# %%
food_emissions.head()
# Out:
#   Country_code_A3           Name        Y_1990        Y_1991        Y_1992  \
# 0             ABW          Aruba     52.467587     58.445779     66.702558
# 1             AFG    Afghanistan  10625.107867  10830.881104  10950.536732
# 2             AGO         Angola  32156.596760  32464.235278  32567.388288
# 3             AIA       Anguilla      2.726608      3.009267      3.130169
# 4             AIR  Int. Aviation   1322.248427   1285.268168   1325.968003
#
#          Y_1993        Y_1994        Y_1995        Y_1996        Y_1997  ...  \
# 0     62.301504     68.506353     75.829265     58.734385     81.162564  ...
# 1  11171.821501  11299.594874  11815.267602  13155.159112  14252.954840  ...
# 2  32602.146277  34115.353337  34801.965224  40930.126655  40057.615721  ...
# 3      3.406827      3.932457      4.488219      4.493260      4.194689  ...
# 4   1352.131430   1424.838702   1481.416851   1541.112346   1620.190699  ...
#
#          Y_2009        Y_2010        Y_2011        Y_2012        Y_2013  \
# 0    159.364420    141.075838    135.129301    173.603909    169.526161
# 1  18810.398534  20963.797333  21558.233158  21216.818799  20942.206787
# 2  65693.104142  67693.467207  66277.366276  67652.087410  67200.277612
# 3      5.795507      6.373054      6.660545      6.705420      6.993232
# 4   2216.413310   2339.399901   2426.222186   2445.366423   2487.015536
#
#          Y_2014        Y_2015        Y_2016        Y_2017        Y_2018
# 0    172.058516    169.902421    172.877401    158.317865    154.667162
# 1  21451.730195  21147.538782  21050.778267  21302.708366  21196.132147
# 2  68146.581224  69470.341229  69064.557603  71539.342723  66445.751315
# 3      7.027910      7.078796      7.159170      7.272695      7.181544
# 4   2570.114990   2712.218964   2831.883565   2990.773933   3116.257046
#
# [5 rows x 31 columns]

# %%
shares.head()
# Out:
#   Country_code_A3      1990      1991      1992      1993      1994      1995  \
# 0             ABW  0.094646  0.091967  0.094180  0.094255  0.095524  0.095044
# 1             AFG  0.945286  0.956797  1.043980  1.052542  1.053925  1.049888
# 2             AGO  0.260012  0.262357  0.265100  0.257833  0.249269  0.241900
# 3             AIA  0.315645  0.294148  0.293971  0.265715  0.243296  0.229146
# 4             AIR  0.005050  0.005049  0.005048  0.005048  0.005047  0.005047
#
#        1996      1997      1998  ...      2009      2010      2011      2012  \
# 0  0.108836  0.099570  0.125348  ...  0.137071  0.132087  0.144212  0.142401
# 1  1.052223  1.050910  1.043679  ...  0.744965  0.718972  0.632209  0.670341
# 2  0.263905  0.262938  0.280048  ...  0.368343  0.358507  0.305326  0.367013
# 3  0.230939  0.249530  0.254434  ...  0.237673  0.224758  0.218826  0.219834
# 4  0.005047  0.005047  0.005047  ...  0.005047  0.005047  0.005047  0.005047
#
#        2013      2014      2015      2016      2017      2018
# 0  0.136197  0.140872  0.139143  0.148309  0.167106  0.167886
# 1  0.703655  0.724509  0.720585  0.744354  0.694031  0.689524
# 2  0.333412  0.366560  0.328805  0.372303  0.380338  0.365586
# 3  0.215168  0.216224  0.216742  0.216764  0.215284  0.217982
# 4  0.005047  0.005047  0.005047  0.005047  0.005046  0.005046
#
# [5 rows x 30 columns]

# %%
country_definition.head()
country_definition.rename(columns={'Country ISO code': 'Country_code_A3'})
# Out:
#     Country_code_A3   Country name     Regional grouping Country class
# 0               ABW          Aruba  Rest Central America    Developing
# 1               AFG    Afghanistan               India +    Developing
# 2               AGO         Angola       Southern_Africa    Developing
# 3               AIA       Anguilla  Rest Central America    Developing
# 4               AIR  Int. Aviation         Int. Aviation             0
# ..              ...            ...                   ...           ...
# 219             WSM          Samoa               Oceania    Developing
# 220             YEM          Yemen           Middle_East    Developing
# 221             ZAF   South Africa       Southern_Africa    Developing
# 222             ZMB         Zambia       Southern_Africa    Developing
# 223             ZWE       Zimbabwe       Southern_Africa    Developing
#
# [224 rows x 4 columns]

# %%
sector.head()
sector['C_group_IM24_sh'] = sector['C_group_IM24_sh'].str[4:]
sector['Substance'] = sector['Substance'].str[8:]
sector.head()
# Out:
#   Country_code_A3     Name  C_group_IM24_sh dev_country Substance  \
# 0             AGO   Angola  Southern_Africa           D       CO2
# 1             AGO   Angola  Southern_Africa           D       CH4
# 2             AGO   Angola  Southern_Africa           D       N2O
# 3             ALB  Albania   Central Europe           I       CO2
# 4             ALB  Albania   Central Europe           I       N2O
#
#     FOOD_system_stage      Y_1990      Y_1991      Y_1992      Y_1993  ...  \
# 0  LULUC (Production)  10273.5451  10273.5451  10273.5451  10273.5451  ...
# 1  LULUC (Production)   7662.4856   7662.4856   7662.4856   7662.4856  ...
# 2  LULUC (Production)   5009.7985   5009.7985   5009.7985   5009.7985  ...
# 3  LULUC (Production)    116.8068    116.8068    116.8068    116.8068  ...
# 4  LULUC (Production)     12.4815     12.4815     12.4815     12.4815  ...
#
#        Y_2009      Y_2010      Y_2011      Y_2012      Y_2013      Y_2014  \
# 0  35606.0653  35605.4601  35604.1556  35604.1556  35604.1556  35602.6343
# 1   6739.5328   7193.0068   6248.5080   6645.6348   5922.2156   6228.5104
# 2   5869.6705   6261.4995   5445.1405   5788.2890   5163.1805   5427.7300
# 3    116.6195    116.6195    116.6195    116.6195    116.5582    116.5582
# 4     12.4550     12.4550     12.4550     12.4550     12.4550     12.4550
#
#        Y_2015      Y_2016      Y_2017      Y_2018
# 0  35601.0571  35597.6207  35597.6207  35592.0828
# 1   6667.6736   6293.3276   7681.6264   4870.0764
# 2   5807.0510   5483.2475   6682.9290   4252.8790
# 3    116.4970    116.3398    116.3398    114.1346
# 4     12.4550     12.4020     12.4020     12.1900
#
# [5 rows x 35 columns]

# %%
sector_grouped = sector.groupby('Substance').agg({col: 'mean' for col in sector.columns if col.startswith('Y_') and int(col[2:]) in range(2000, 2019)})
sector_grouped.reset_index(inplace=True)

# %%
sector_grouped.head()
# Out:
#   Substance       Y_2000       Y_2001       Y_2002       Y_2003       Y_2004  \
# 0       CH4  3468.901109  3445.250641  3557.587477  3552.908858  3677.921306
# 1       CO2  5164.151782  4809.229537  5077.907736  4977.987143  5290.100022
# 2   F-gases   439.496221   581.020709   724.289410   874.838640  1038.131259
# 3       N2O  1138.107510  1151.134022  1176.107839  1197.135381  1227.171098
#
#         Y_2005       Y_2006       Y_2007       Y_2008       Y_2009  \
# 0  3682.161278  3789.731727  3739.625982  3790.448964  3869.155068
# 1  5233.821249  5487.533882  5279.327591  5276.384662  5456.675428
# 2  1249.587095  1381.310860  1534.016018  1682.016494  1818.873720
# 3  1234.601673  1254.261791  1274.749513  1262.284181  1275.396034
#
#         Y_2010       Y_2011       Y_2012       Y_2013       Y_2014  \
# 0  3847.421110  3900.094868  3939.809666  3969.375541  4054.174238
# 1  5324.078515  5217.191819  5232.576683  5252.865140  5442.671279
# 2  1965.464577  2162.805610  2350.056626  2523.611071  2693.285591
# 3  1299.041979  1316.231303  1323.072976  1341.972845  1344.639071
#
#         Y_2015       Y_2016       Y_2017       Y_2018
# 0  4108.468517  4064.989788  4099.754877  4155.795761
# 1  5452.280591  4951.579246  4947.085820  5090.141843
# 2  2829.561225  3048.584326  3255.649411  3474.531062
# 3  1363.648486  1376.994615  1380.959168  1370.672111

# %%
tidy_sector_grouped = pd.melt(sector_grouped, id_vars=['Substance'], 
                  value_vars=[col for col in sector_grouped.columns if col.startswith('Y_')],
                  var_name='Year', value_name='Emissions')

# %%
tidy_sector_grouped.head()
# Out:
#   Substance    Year    Emissions
# 0       CH4  Y_2000  3468.901109
# 1       CO2  Y_2000  5164.151782
# 2   F-gases  Y_2000   439.496221
# 3       N2O  Y_2000  1138.107510
# 4       CH4  Y_2001  3445.250641

# %%
tidy_sector_grouped['Year'] = tidy_sector_grouped['Year'].str[2:].astype(int)

# %%
tidy_sector_grouped.head()
# Out:
#   Substance  Year    Emissions
# 0       CH4  2000  3468.901109
# 1       CO2  2000  5164.151782
# 2   F-gases  2000   439.496221
# 3       N2O  2000  1138.107510
# 4       CH4  2001  3445.250641

# %% [markdown]
# ## This chart will give us a chronological understanding of the types of emissions and if any particlar one GHG has been on the rise/fall along with their relative contributions. We see that F-gases is on the rise, it might be worthwhile to investigate which region, or which country has been contributing to this rise.

# %%
alt.Chart(tidy_sector_grouped).mark_line(color= 'green', strokeWidth=3).encode(
    x=alt.X( "Year:O", title = 'Year'),
    y=alt.Y("Emissions", axis=alt.Axis(title=None, labels=True), scale=alt.Scale(zero=False))
).properties(
    width = 280,
    height = 50
).facet(
    facet = alt.Facet("Substance:N", title = 'Substance'),
    columns = 1,
).resolve_scale(
    y = 'shared'
)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.FacetChart(...)

# %%
system_grouped = sector.groupby('FOOD_system_stage').agg({col: 'mean' for col in sector.columns if col.startswith('Y_') and int(col[2:]) in range(2000, 2019)})
system_grouped.reset_index(inplace=True)
system_grouped.head()
# Out:
#     FOOD_system_stage        Y_2000        Y_2001        Y_2002        Y_2003  \
# 0         Consumption    601.155866    608.492452    609.843693    630.036593
# 1         End_of_Life   2489.958485   2496.321136   2522.423577   2560.973707
# 2  LULUC (Production)  12922.860676  11406.475826  12728.188543  11878.903064
# 3           Packaging   1034.684697   1057.530008   1045.041397   1128.707882
# 4          Processing    744.151526    762.807277    778.913818    786.607214
#
#          Y_2004        Y_2005        Y_2006        Y_2007        Y_2008  \
# 0    648.899340    661.801470    668.337936    679.303828    668.270522
# 1   2601.479717   2632.011249   2678.060532   2707.117236   2730.098060
# 2  12828.530377  12126.913632  13093.379948  11693.587944  11597.278943
# 3   1282.456936   1357.356076   1397.574072   1471.314237   1497.254733
# 4    858.997031    885.650869    913.556951    945.323990    971.926322
#
#          Y_2009        Y_2010        Y_2011        Y_2012        Y_2013  \
# 0    666.347258    687.278191    699.234502    703.273702    716.677797
# 1   2766.858454   2790.886603   2835.427301   2867.959900   2916.702007
# 2  12611.131519  11731.595561  11103.015476  11225.158329  11134.183626
# 3   1473.929699   1514.797142   1612.945801   1552.064342   1542.309294
# 4    965.001272    972.828936    973.381078    987.776254   1002.181602
#
#          Y_2014        Y_2015       Y_2016       Y_2017        Y_2018
# 0    721.183119    724.117345   730.402266   742.082765    759.964703
# 1   2956.918587   3003.704437  3052.579077  3107.962965   3152.400916
# 2  12038.554787  12166.145982  9971.012888  9855.310419  10285.529537
# 3   1573.536730   1546.499389  1504.080568  1516.065757   1553.282239
# 4    989.095426    987.771907   996.270172   985.534419   1012.676046

# %%
tidy_system_grouped = pd.melt(system_grouped, id_vars=['FOOD_system_stage'], 
                  value_vars=[col for col in sector_grouped.columns if col.startswith('Y_')],
                  var_name='Year', value_name='system_stage')

tidy_system_grouped.head()
# Out:
#     FOOD_system_stage    Year  system_stage
# 0         Consumption  Y_2000    601.155866
# 1         End_of_Life  Y_2000   2489.958485
# 2  LULUC (Production)  Y_2000  12922.860676
# 3           Packaging  Y_2000   1034.684697
# 4          Processing  Y_2000    744.151526

# %%
tidy_system_grouped['Year'] = tidy_system_grouped['Year'].str[2:].astype(int)
tidy_system_grouped.head()
# Out:
#     FOOD_system_stage  Year  system_stage
# 0         Consumption  2000    601.155866
# 1         End_of_Life  2000   2489.958485
# 2  LULUC (Production)  2000  12922.860676
# 3           Packaging  2000   1034.684697
# 4          Processing  2000    744.151526

# %% [markdown]
# ## This chart will give us a chronological understanding of food processes and if any particlar one has been on the rise/fall along with their relative contributions. It might be good to give reader some context to why production systems emit more than other food system processes.

# %%
 alt.Chart(tidy_system_grouped).mark_line(color= 'darkblue', strokeWidth=3).encode(
    x = alt.X( "Year:O", title = 'Year'),
    y = alt.Y( "system_stage:Q", axis=alt.Axis(labels=True, title=None), scale=alt.Scale(zero=False))
).properties(
    width = 280,
    height = 50
).facet(
    facet = alt.Facet("FOOD_system_stage:N", title = 'System Stage'),
    columns = 1,
).resolve_scale(
    y = 'shared'
)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.FacetChart(...)

# %%
stacked_data = sector.groupby(['C_group_IM24_sh', 'FOOD_system_stage'])['Y_2018'].sum().reset_index()
stacked_data.head()
# Out:
#   C_group_IM24_sh   FOOD_system_stage        Y_2018
# 0       Asia-Stan         Consumption   2756.628904
# 1       Asia-Stan         End_of_Life  13718.186454
# 2       Asia-Stan  LULUC (Production)      2.617000
# 3       Asia-Stan           Packaging   5807.858537
# 4       Asia-Stan          Processing   7044.068443

# %% [markdown]
# ## This chart shows the distribution of emissions by food system stages. This will show the reader a regional distribution of emissions and if any 1 particilar food process is contributing to  a large chunk of their emissions. In this way, readers can also identify policy puzzles between countries. Example: Why is region a not contributing to gas x when a similar region b does.

# %%
alt.Chart(stacked_data).mark_bar().encode(
    x = alt.X('C_group_IM24_sh:N', title='Region'),
    y = alt.Y('Y_2018:Q', title='GHG Emissions (Kilotons)'),
    color = alt.Color('FOOD_system_stage', title='Food System Stage')
).properties(
    title="GHG Emissions in Food System Stages by Regions"
)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
#IDeas
# Chloropleth for total emissions
# boxplot for industrialized and non-indistrialized
# treemap for industrialized -> countries/regions -> substance/total emissions
# heatmap between food production stage and type of emissions
# try something with per capita
# grouped scatter plot between industrialized and non-industrialized

# %%
grouped_data = sector.groupby(['C_group_IM24_sh', 'Substance'])['Y_2018'].sum().reset_index()
grouped_data.rename(columns={'Y_2018': 'total_emissions'}, inplace=True)

# %% [markdown]
# ## This chart shows the distribution of emissions by regions. This will show the reader a regional distribution of emissions and if any 1 particilar country is emitting a lot of one particular GHG. It can also be used to show that GHG emissions due to shipping and avaiation are not as big in the food prodcution context.

# %%
alt.Chart(grouped_data).mark_bar().encode(
    x = alt.X('C_group_IM24_sh:N', title='Region'),
    y = alt.Y('total_emissions', title='GHG Emissions (Kilotons)'),
    color = alt.Color('Substance', title='Food System Stage')
).properties(
    title="GHG Emissions by Regions"
)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %% [markdown]
# ## This chart shows the relationship between food production stages and the respective GHGs they emit. By knowing this, we can get to know which processes contribute to the most in GHG category. This is a graph which can be substantiated

# %%
data_2018 = sector[['Substance', 'FOOD_system_stage', 'Y_2018']]

aggregated_data = data_2018.groupby(['Substance', 'FOOD_system_stage'])['Y_2018'].sum().reset_index()


alt.Chart(aggregated_data).mark_rect().encode(
    x=alt.X('FOOD_system_stage:N', title='Food System Stage'),
    y=alt.Y('Substance:N', title='Substance'),
    color=alt.Color('Y_2018:Q', 
                    scale=alt.Scale(scheme='viridis'),
                    title='Emissions in Kiloton'),
).properties(
    title='Emissions by Substance and Food System Stage (2018)',
    width=600,
    height=400
)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %% [markdown]
# ## I want to modify this chart to be able to make it more striking as it will be at the beginning. I can possibly do this by cutting the y-axis or plotting the growth instead of absolute numbers.

# %%
year_columns = [col for col in sector.columns if col.startswith('Y_')]

# Melt the dataframe to get years in a single column
melted_data = pd.melt(sector, id_vars=['Country_code_A3', 'Substance'], 
                      value_vars=year_columns, 
                      var_name='Year', value_name='Emissions')

# Convert Year to numeric, removing 'Y_' prefix
melted_data['Year'] = pd.to_numeric(melted_data['Year'].str.replace('Y_', ''))

# Calculate total emissions for each year
yearly_totals = melted_data.groupby('Year')['Emissions'].sum().reset_index()

# Create the lollipop chart
base = alt.Chart(yearly_totals).encode(
    x=alt.X('Year:O', axis=alt.Axis(title='Year', labelAngle=45)),
    y=alt.Y('Emissions:Q', axis =alt.Axis( title = 'Emissions (Kilotons)'))
).properties(
    title = "Total GHG Emissions in the World (1990 - 2018)"
)

lines = base.mark_rule().encode(
    y='Emissions:Q'
)

points = base.mark_circle(size=100).encode(
    y='Emissions:Q',
    color=alt.value('steelblue')
)


# Combine all layers
final_chart = (lines + points).configure_axis(
    labelFontSize=12,
    titleFontSize=14
).configure_title(
    fontSize=16
)

# Display the chart
final_chart
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## This chart will show that developing countries are emitting more GHG compared to industrialized nations, but it is not the case for F-gases, which according to the previous chart is rising. I am unsure on how to make the boxes in the boxplots wider and more visible.

# %%
data_2018 = sector[['dev_country', 'Substance', 'Y_2018']]
data_2018 = data_2018[data_2018['dev_country'] != 0]
data_2018['dev_country'] = data_2018['dev_country'].replace('D', 'Developing')
data_2018['dev_country'] = data_2018['dev_country'].replace('I', 'Industrialized')


alt.Chart(data_2018).mark_boxplot().encode(
    x=alt.X('dev_country:N', title="a", axis=None),
    y=alt.Y('Y_2018:Q', title='Emissions in 2018'),
    color=alt.Color('dev_country:N', title='Country Type'),
    facet=alt.Facet('Substance:N', title='GHG', columns=4)
).properties(
    width=150,
    height=200,
    title='Emissions in 2018: Industrialized vs Developing Countries by Substance'
).configure_mark(
    opacity=0.5,
)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %% [markdown]
# ## This chart will show that the countries' increase in emissions have been really large over the last ~10 years. I don't want this chart to be misleading, so it might be a good idea to sort this by population as well or maybe use absolute changes as they are more important in climate change discussions.

# %%
mean_emissions = sector.groupby(['Name', 'dev_country'])[['Y_2010', 'Y_2018']].mean().reset_index()
mean_emissions.head()

mean_emissions = mean_emissions[mean_emissions['dev_country'] != 0]
mean_emissions['dev_country'] = mean_emissions['dev_country'].replace('D', 'Developing')
mean_emissions['dev_country'] = mean_emissions['dev_country'].replace('I', 'Industrialized')

mean_emissions['percentage_change'] = ((mean_emissions['Y_2018'] - mean_emissions['Y_2010']) / mean_emissions['Y_2010']) * 100
mean_emissions.replace([float('inf'), -float('inf')], pd.NA, inplace=True)

mean_emissions['percentage_change'] = pd.to_numeric(mean_emissions['percentage_change'], errors='coerce')

mean_emissions.dropna(subset=['percentage_change'], inplace=True)

top_10_countries = mean_emissions.nlargest(10, 'percentage_change').sort_values(by='percentage_change', ascending=False)

alt.Chart(top_10_countries).mark_bar().encode(
    x=alt.X('percentage_change:Q', title='Percentage Change in Emissions (2010 to 2018)'),
    y=alt.Y('Name:N', title='Country'),
    color='dev_country:N'
).properties(
    title='Top 10 Countries by Percentage Change in Emissions (2010-2018)',
    width=600,
    height=300
)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)
